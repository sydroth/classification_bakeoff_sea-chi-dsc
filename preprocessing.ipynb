# %%
import pandas as pd

# %%
data = pd.read_csv('train_data.csv')

# %%
# drop id

data.drop(columns='ID', axis=1, inplace=True)

# %%
# drop rows with 0/unknown values in EDUCATION

data = data[data['EDUCATION'] != 0]

# %%
# combine 5 and 6 in education

data['EDUCATION'].replace(to_replace=6, value=5, inplace=True)

# %%
# drop 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6'

# data.drop(columns=['BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6'],
#         axis=1, inplace=True)

# %%
data['default payment next month'].value_counts()
# Out:
# 0    18680
# 1     5308
# Name: default payment next month, dtype: int64

# %%
data
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0         350000    1          1         2   37     -2     -2     -2     -2
# 1          50000    2          2         1   37      2      2      2      0
# 2          50000    2          1         2   23     -1     -1     -1     -1
# 3          20000    1          3         1   56      0      0      0      0
# 4         110000    2          2         2   32      0      0      0      0
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 23994      50000    2          1         2   24      0      0      0     -2
# 23995     250000    1          3         1   44     -1     -1     -1     -1
# 23996      50000    1          3         2   26      2      0      0      2
# 23997     110000    2          2         1   38      0      0      0      0
# 23998     150000    1          1         2   34      2      3      2      0
#
# ...

# %%
data.rename(columns={'default payment next month': 'target'}, inplace=True )

# %%
data.to_csv(r'final.csv', index = False)
